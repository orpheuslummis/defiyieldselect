# %%
import matplotlib.pyplot as plt
import pandas as pd
from sktime.utils.plotting import plot_series

# %%
PATH_DATA_XLSX = '../data/xlsx'
PATH_DATA_CSV = '../data/csv'

# %%
# getting files

from os import listdir
from os.path import isfile, join

xlsxfiles = [f for f in listdir(PATH_DATA_XLSX) if isfile(join(PATH_DATA_XLSX, f))]
csvfiles = [f for f in listdir(PATH_DATA_CSV) if isfile(join(PATH_DATA_CSV, f))]

# %%
print(xlsxfiles)
# Out:
# ['Borrow4DEC.xlsx', 'Lend4DEC.xlsx', 'BorrowOCT31.xlsx', 'LendOCT31.xlsx']

# %%
print(csvfiles)
# Out:
# ['Pairs-Price_31OCT.csv', 'PairPrices4DEC.csv']

# %%
print("xlsxfiles", len(xlsxfiles))
print("csvfiles", len(csvfiles))
# Out:
# xlsxfiles 4
# csvfiles 2

# %%
PATH = f"{PATH_DATA_XLSX}/{xlsxfiles[0]}"

data = pd.read_excel(PATH, index_col=0)
data.head()
# Out:
#                                     Time              ASUSD  \
# Platform
# Aave      2020-10-10T19:48:30.438035456Z  45890356713640496
# Aave      2020-10-10T19:49:53.165059911Z  45890356713640496
# Aave      2020-10-10T19:51:14.445774448Z  45890356713640496
# Aave      2020-10-10T19:52:36.592969518Z  45890356713640496
# Aave      2020-10-10T19:53:58.036531289Z  45890356713640496
#
#                       AUSDT               ADAI               AYFI  \
# Platform
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
#
#                        AKNC               AETH               AREN  \
# Platform
# Aave      19832611692982600  31640169521277000  13362042572053000
# ...

# %%
print(len(data))
print(data3.columns)
# Out:
# 57876
# Index(['Time', 'ASUSD', 'AUSDT', 'ADAI', 'AYFI', 'AKNC', 'AETH', 'AREN',
#        'ALINK', 'ATUSD', 'AMKR', 'ALEND', 'AREP', 'AENJ', 'AUSDC', 'ASNX',
#        'ABAT', 'ABUSD', 'AZRX', 'AMANA', 'AWBTC', 'ASUSD.1', 'AUSDT.1',
#        'ADAI.1', 'AYFI.1', 'AKNC.1', 'AETH.1', 'AREN.1', 'ALINK.1', 'ATUSD.1',
#        'AMKR.1', 'ALEND.1', 'AREP.1', 'AENJ.1', 'AUSDC.1', 'ASNX.1', 'ABAT.1',
#        'ABUSD.1', 'AZRX.1', 'AMANA.1', 'AWBTC.1'],
#       dtype='object')

# %%
data.iloc[len(data) - 1]['Time']
# Out:
# '2020-12-04T17:26:38.130554028Z'

# %%
PATH = f"{PATH_DATA_XLSX}/{xlsxfiles[1]}"

data2 = pd.read_excel(PATH, index_col=0)
data2.head()
# Out:
#                                     Time               ADAI  \
# Platform
# Aave      2020-10-10T19:48:30.438035456Z  37506682841702496
# Aave      2020-10-10T19:49:53.165059911Z  37506682841702496
# Aave      2020-10-10T19:51:14.445774448Z  37506682841702496
# Aave      2020-10-10T19:52:36.592969518Z  37506682841702496
# Aave      2020-10-10T19:53:58.036531289Z  37506682841702496
#
#                       AUSDC             ATUSD              ASUSD  \
# Platform
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
#
#                    AWBTC              AKNC             ABAT  \
# Platform
# Aave      99307360359226  3232423846207670  973156323988152
# ...

# %%
print(len(data2))
print(data2.columns)
# Out:
# 57876
# Index(['Time', 'ADAI', 'AUSDC', 'ATUSD', 'ASUSD', 'AWBTC', 'AKNC', 'ABAT',
#        'ABUSD', 'AETH', 'AMKR', 'AUSDT', 'AMANA', 'AZRX', 'ASNX', 'AYFI',
#        'ALINK', 'AREN', 'AREP', 'AENJ', 'ALEND', 'ADAI.1', 'AUSDC.1',
#        'ATUSD.1', 'ASUSD.1', 'AWBTC.1', 'AKNC.1', 'ABAT.1', 'ABUSD.1',
#        'AETH.1', 'AMKR.1', 'AUSDT.1', 'AMANA.1', 'AZRX.1', 'ASNX.1', 'AYFI.1',
#        'ALINK.1', 'AREN.1', 'AREP.1', 'AENJ.1', 'ALEND.1'],
#       dtype='object')

# %%
data2.iloc[len(data2) - 1]['Time']
# Out:
# '2020-12-04T17:26:38.130554028Z'

# %%
PATH = f"{PATH_DATA_XLSX}/{xlsxfiles[2]}"

data3 = pd.read_excel(PATH, index_col=0)
data3.head()
# Out:
#                                     Time              ASUSD  \
# Platform
# Aave      2020-10-10T19:48:30.438035456Z  45890356713640496
# Aave      2020-10-10T19:49:53.165059911Z  45890356713640496
# Aave      2020-10-10T19:51:14.445774448Z  45890356713640496
# Aave      2020-10-10T19:52:36.592969518Z  45890356713640496
# Aave      2020-10-10T19:53:58.036531289Z  45890356713640496
#
#                       AUSDT               ADAI               AYFI  \
# Platform
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
# Aave      44141825491673200  60779224199156096  28654820705014700
#
#                        AKNC               AETH               AREN  \
# Platform
# Aave      19832611692982600  31640169521277000  13362042572053000
# ...

# %%
set(data3.columns)
# Out:
# {'ABAT',
#  'ABAT.1',
#  'ABUSD',
#  'ABUSD.1',
#  'ADAI',
#  'ADAI.1',
#  'AENJ',
#  'AENJ.1',
#  'AETH',
#  'AETH.1',
#  'AKNC',
#  'AKNC.1',
#  'ALEND',
#  'ALEND.1',
#  'ALINK',
#  'ALINK.1',
#  'AMANA',
#  'AMANA.1',
#  'AMKR',
#  'AMKR.1',
#  'AREN',
#  'AREN.1',
#  'AREP',
#  'AREP.1',
#  'ASNX',
#  'ASNX.1',
#  'ASUSD',
#  'ASUSD.1',
#  'ATUSD',
#  'ATUSD.1',
#  'AUSDC',
#  'AUSDC.1',
#  'AUSDT',
#  'AUSDT.1',
#  'AWBTC',
#  'AWBTC.1',
#  'AYFI',
#  'AYFI.1',
#  'AZRX',
#  'AZRX.1',
#  'Time'}

# %%
PATH = f"{PATH_DATA_XLSX}/{xlsxfiles[3]}"

data4 = pd.read_excel(PATH, index_col=0)
data4.head()
# Out:
#                                     Time               ADAI  \
# Platform
# Aave      2020-10-10T19:48:30.438035456Z  37506682841702496
# Aave      2020-10-10T19:49:53.165059911Z  37506682841702496
# Aave      2020-10-10T19:51:14.445774448Z  37506682841702496
# Aave      2020-10-10T19:52:36.592969518Z  37506682841702496
# Aave      2020-10-10T19:53:58.036531289Z  37506682841702496
#
#                       AUSDC             ATUSD              ASUSD  \
# Platform
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
# Aave      12434432615852200  2726413009429190  32940425443375300
#
#                    AWBTC              AKNC             ABAT  \
# Platform
# Aave      99307360359226  3232423846207670  973156323988152
# ...

# %%
PATH = f"{PATH_DATA_CSV}/{csvfiles[0]}"

datacsv = pd.read_csv(PATH, index_col=0)
datacsv.head()
# Out:
#             Price                            Time
# Pair
# REN/ETH  0.000859    2020-10-10T19:48:44.2540926Z
# REN/ETH  0.000859     2020-10-10T19:49:15.780552Z
# REN/ETH  0.000859    2020-10-10T19:50:17.5137016Z
# REN/ETH  0.000859  2020-10-10T19:51:20.840512299Z
# REN/ETH  0.000859    2020-10-10T19:52:29.3277823Z

# %%
set(datacsv.index)
# Out:
# {'BAT/ETH',
#  'DAI/ETH',
#  'ENJ/ETH',
#  'KNC/ETH',
#  'LEND/ETH',
#  'LINK/ETH',
#  'MANA/ETH',
#  'MKR/ETH',
#  'REN/ETH',
#  'REP/ETH',
#  'SNX/ETH',
#  'SUSD/ETH',
#  'TUSD/ETH',
#  'USDC/ETH',
#  'USDT/ETH',
#  'WBTC/ETH',
#  'YFI/ETH',
#  'ZRX/ETH'}

# %%
PATH = f"{PATH_DATA_CSV}/{csvfiles[1]}"

datacsv2 = pd.read_csv(PATH, index_col=0)
datacsv2.head()
# Out:
#             Price                            Time
# Pair
# REN/ETH  0.000859    2020-10-10T19:48:44.2540926Z
# REN/ETH  0.000859     2020-10-10T19:49:15.780552Z
# REN/ETH  0.000859    2020-10-10T19:50:17.5137016Z
# REN/ETH  0.000859  2020-10-10T19:51:20.840512299Z
# REN/ETH  0.000859    2020-10-10T19:52:29.3277823Z

# %%
timeseries_pairs = load_data()

for timeseries in timeseries_pairs:
    print(timeseries)
    plot_series(timeseries_pairs[timeseries])
    plt.show()
    break

# %%
from os import walk

f = []
for (dirpath, dirnames, filenames) in walk(PATH_DATA):
    print(filenames)
    break

# %%
onlyfiles
# Out:
# ['Borrow4DEC.xlsx',
#  'Lend4DEC.xlsx',
#  'Pairs-Price_31OCT.csv',
#  'BorrowOCT31.xlsx',
#  'PairPrices4DEC.csv',
#  'LendOCT31.xlsx']
